# %%
import pandas as pd
import geopandas as gpd
import biogeme.results as res
import random as rd
from math import log, exp

# %%
# Cargamos nuestra ciudad sintética
cells = gpd.read_file('ciudad_sintetica.shp')
cells.head()
# Out:
#    cell          area      m2_op  acc_op_cam   acc_op_veh  \
# 0     1  25980.762114   1.496370   21.999698  3261.594956
# 1     2  25980.762114   0.293320   20.939344  3283.642413
# 2     3  25980.762114   3.416329   25.762190  3294.544635
# 3     4  25980.762114  16.222386   47.757336  3293.653747
# 4     5  25980.762114   8.038769   51.997028  3280.187080
#
#                                             geometry
# 0  POLYGON ((0.000 1000.000, 100.000 1000.000, 15...
# 1  POLYGON ((0.000 826.795, 100.000 826.795, 150....
# 2  POLYGON ((0.000 653.590, 100.000 653.590, 150....
# 3  POLYGON ((0.000 480.385, 100.000 480.385, 150....
# 4  POLYGON ((0.000 307.180, 100.000 307.180, 150....

# %%
# Agregamos Agentes H1 y H2 en nuestra ciudad, este paso es completamente 
# sintético (Ustedes ya los tienen por medio de la foto de la ciudad desde el SII)
def gen_h1_h2(row, df):
    pond_h1 = (row['acc_op_veh']+row['acc_op_cam'])/(df['acc_op_veh'].sum()+df['acc_op_cam'].sum())
    pond_h2 = (row['acc_op_veh'])/df['acc_op_veh'].sum()
    h1 = 3*int(rd.expovariate(pond_h1))
    h2 = 4*int(rd.expovariate(pond_h2))
    return pd.Series([h1, h2])
cells[['h1','h2']] = cells.apply(lambda row: gen_h1_h2(row, cells), axis = 1)
cells.head()
# Out:
#    cell          area      m2_op  acc_op_cam   acc_op_veh  \
# 0     1  25980.762114   1.496370   21.999698  3261.594956
# 1     2  25980.762114   0.293320   20.939344  3283.642413
# 2     3  25980.762114   3.416329   25.762190  3294.544635
# 3     4  25980.762114  16.222386   47.757336  3293.653747
# 4     5  25980.762114   8.038769   51.997028  3280.187080
#
#                                             geometry   h1   h2
# 0  POLYGON ((0.000 1000.000, 100.000 1000.000, 15...   66   56
# 1  POLYGON ((0.000 826.795, 100.000 826.795, 150....  114  556
# 2  POLYGON ((0.000 653.590, 100.000 653.590, 150....  378  112
# 3  POLYGON ((0.000 480.385, 100.000 480.385, 150....  108  216
# 4  POLYGON ((0.000 307.180, 100.000 307.180, 150....   84  712

# %%
cells.plot(column = 'h1')
# Out:
# <AxesSubplot:>

# %%
cells.plot(column = 'h2')
# Out:
# <AxesSubplot:>

# %%
# Definimos funciones bhi (de DP) ficticias (ustedes las cargan desde BIOGEME)

bhi_h1 = lambda acc_cam, acc_veh, n_h2: 0.01*acc_cam - 0.0015*acc_veh - 0.002*n_h2 
bhi_h2 = lambda acc_cam, acc_veh, n_h2: 0.02*acc_cam - 0.0017*acc_veh + 0.003*n_h2

# %%
# Incializamos la oferta por zona 
cells['s_i'] = cells['h1'] + cells['h2']
cells.head()
# Out:
#    cell          area      m2_op  acc_op_cam   acc_op_veh  \
# 0     1  25980.762114   1.496370   21.999698  3261.594956
# 1     2  25980.762114   0.293320   20.939344  3283.642413
# 2     3  25980.762114   3.416329   25.762190  3294.544635
# 3     4  25980.762114  16.222386   47.757336  3293.653747
# 4     5  25980.762114   8.038769   51.997028  3280.187080
#
#                                             geometry   h1   h2  s_i
# 0  POLYGON ((0.000 1000.000, 100.000 1000.000, 15...   66   56  122
# 1  POLYGON ((0.000 826.795, 100.000 826.795, 150....  114  556  670
# 2  POLYGON ((0.000 653.590, 100.000 653.590, 150....  378  112  490
# 3  POLYGON ((0.000 480.385, 100.000 480.385, 150....  108  216  324
# 4  POLYGON ((0.000 307.180, 100.000 307.180, 150....   84  712  796

# %%
# Previo a iniciar

## H1 y H2 Observados
H1 = cells['h1'].sum()
H2 = cells['h2'].sum()
print(f"H1 observado: {H1}")
print(f"H2 observado: {H2}\n\n")

## Objetivos de H1 y H2
H1_obj = 9500
H2_obj = (H1+H2) - H1_obj
agentes = {'h1': H1_obj, 'h2': H2_obj}
print(f"H1 objetivo: {H1_obj}")
print(f"H2 objetivo: {H2_obj}")

## Parametros Mus
mu = 1
mu_oferta = 0.15

## B_h inicial
b_h = {'h1': 0, 'h2': 0}

# Oferta total
S = cells['s_i'].sum()
# Out:
# H1 observado: 9477
# H2 observado: 13148
#
#
# H1 objetivo: 9500
# H2 objetivo: 13125

# %%
def renta(row):
    global agentes, mu
    
    suma = 0
    for h in agentes:
        suma += agentes[h] * exp(mu * (row[f'bhi_{h}'] + b_h[h])) 
    
    r = (1/mu) * log(suma)
    return r

# %%
def prob(row):
    global agentes, mu
    
    agentes[h] * exp(mu * (row[f'bhi_{h}'] + b_h[h] - row['r_i'])) 
    
    r = (1/mu) * log(suma)
    return r

# %%
iteraciones = [cells.copy()]
a = True
while True:
    iteraciones.append(iteraciones[-1].copy())
    current = iteraciones[-1]
    
    # Calculamos los bhi por tipo de hogar
    current['bhi_h1'] = current.apply(lambda row: bhi_h1(row['acc_op_cam'], row['acc_op_veh'], row['h2']), axis = 1)
    current['bhi_h2'] = current.apply(lambda row: bhi_h2(row['acc_op_cam'], row['acc_op_veh'], row['h2']), axis = 1)

    # Calculamos las rentas en cada celda
    current['r_i'] = current.apply(lambda row: renta(row), axis = 1)
    
    # Calculamos las probabilidades
    for h in agentes:
        current[f'phi_{h}'] = current.apply(lambda row: agentes[h] * exp(mu * (row[f'bhi_{h}'] + b_h[h] - row['r_i'])), axis = 1)
        
    # Actualizamos los agentes
    for h in agentes:
        current[f'{h}'] = current.apply(lambda row: row['s_i'] * row[f'phi_{h}'], axis = 1)
    
    # Actualizamos los bh para la siguiente iteracion
    for h in b_h:
        c = current.copy()
        c['sumando'] = c.apply(lambda row: row['s_i']*exp(mu*row[f'bhi_{h}']-row['r_i']), axis = 1)
        b_h[h] = -1/mu * log(c['sumando'].sum())
    
    # Determinamos el error
    current['err'] = abs(current['h1'] + current['h2'] - current['s_i'])
    error = abs(current['h1'].sum()-agentes['h1']) + abs(current['h2'].sum()-agentes['h2']) + current['err'].sum()
    print(error)
    
    if error < 0.001:
        break
        
# 23  POLYGON ((450.000 740.192, 550.000 740.192, 60...  178.525531  171.239575
# 24  POLYGON ((450.000 566.987, 550.000 566.987, 60...  166.670796  221.378143
# 25  POLYGON ((450.000 393.782, 550.000 393.782, 60...  130.350489  409.556512
# 26  POLYGON ((450.000 220.577, 550.000 220.577, 60...  170.852051  211.559009
# 27  POLYGON ((450.000 47.372, 550.000 47.372, 600....  197.412250   98.854399
# 28  POLYGON ((600.000 1000.000, 700.000 1000.000, ...  126.072194  440.159220
# 29  POLYGON ((600.000 826.795, 700.000 826.795, 75...  148.300928  303.343272
# 30  POLYGON ((600.000 653.590, 700.000 653.590, 75...  172.778266  190.072074
# 31  POLYGON ((600.000 480.385, 700.000 480.385, 75...  142.724861  330.061967
# 32  POLYGON ((600.000 307.180, 700.000 307.180, 75...  138.876883  356.640770
# 33  POLYGON ((600.000 133.975, 700.000 133.975, 75...  179.767156  173.273918
# 34  POLYGON ((600.000 -39.230, 700.000 -39.230, 75...  201.273460   74.357833
# 35  POLYGON ((750.000 1086.603, 850.000 1086.603, ...   97.867354  749.617007
# 36  POLYGON ((750.000 913.397, 850.000 913.397, 90...  112.922951  532.956348
# 37  POLYGON ((750.000 740.192, 850.000 740.192, 90...  169.920267  200.936446
# 38  POLYGON ((750.000 566.987, 850.000 566.987, 90...  170.973168  196.144599
# 39  POLYGON ((750.000 393.782, 850.000 393.782, 90...  162.848623  234.535903
# 40  POLYGON ((750.000 220.577, 850.000 220.577, 90...  170.960213  205.619100
# 41  POLYGON ((750.000 47.372, 850.000 47.372, 900....  180.741855  172.731661
# 42  POLYGON ((900.000 1000.000, 1000.000 1000.000,...   90.409967  998.521484
# 43  POLYGON ((900.000 826.795, 1000.000 826.795, 1...  113.878241  521.632524
# 44  POLYGON ((900.000 653.590, 1000.000 653.590, 1...  108.335252  569.478850
# 45  POLYGON ((900.000 480.385, 1000.000 480.385, 1...  127.177374  420.183174
# 46  POLYGON ((900.000 307.180, 1000.000 307.180, 1...  179.484744  167.187584
# 47  POLYGON ((900.000 133.975, 1000.000 133.975, 1...  174.378677  196.923176
# 48  POLYGON ((900.000 -39.230, 1000.000 -39.230, 1...  180.593505  180.224996
# 49  POLYGON ((1050.000 1086.603, 1150.000 1086.603...  111.759975  572.389480
# 50  POLYGON ((1050.000 913.397, 1150.000 913.397, ...  117.916242  500.817774
# 51  POLYGON ((1050.000 740.192, 1150.000 740.192, ...   98.120316  718.170275
# 52  POLYGON ((1050.000 566.987, 1150.000 566.987, ...   92.673620  842.531541
# 53  POLYGON ((1050.000 393.782, 1150.000 393.782, ...  167.682597  219.566759
# 54  POLYGON ((1050.000 220.577, 1150.000 220.577, ...  194.461510  106.089462
# 55  POLYGON ((1050.000 47.372, 1150.000 47.372, 12...  175.652360  200.069960
#
#             s_i    bhi_h1    bhi_h2        r_i    phi_h1    phi_h2  \
# 0    227.672544 -4.590324 -5.050003   5.899525  0.879840  0.120160
# 1    226.072682 -4.635608 -5.109764   5.852513  0.881362  0.118638
# 44   677.814102  0.977147  4.167874  13.172624  0.159830  0.840170
# 45   547.360548 -0.073838  2.652506  11.747521  0.232347  0.767653
# 46   346.672328 -2.317454 -0.857192   8.702670  0.517736  0.482264
# 47   371.301853 -1.957382 -0.304561   9.160238  0.469641  0.530359
# 48   360.818501 -2.084657 -0.555464   8.969303  0.500511  0.499489
# 49   684.149455  1.060989  4.225691  13.234646  0.163356  0.836644
# 50   618.734016  0.545105  3.522609  12.564640  0.190577  0.809423
# 51   816.290591  1.931529  5.453278  14.411939  0.120203  0.879797
# 52   935.205161  2.645060  6.383624  15.318576  0.099094  0.900906
# 53   387.249356 -1.758235  0.042585   9.440595  0.433009  0.566991
# 54   300.550972 -3.046299 -2.121014   7.750918  0.647017  0.352983
# 55   375.722321 -1.883039 -0.221642   9.239139  0.467506  0.532494
#
#              err     exp_ri
# 0   1.421085e-13   2.422812
# 1   5.684342e-14   2.405787
# 2   0.000000e+00   2.420644
# 3   1.989520e-13   2.521223
# 4   8.526513e-14   2.549491
# 5   1.705303e-13   2.533748
# 6   1.136868e-13   2.493718
# 7   5.684342e-14   2.472167
# 8   0.000000e+00   2.595690
# 9   1.989520e-13   2.504735
# 10  8.526513e-14   2.642340
# 11  0.000000e+00   2.879925
# 12  5.684342e-14   2.745009
# 13  5.684342e-14   2.776685
# 14  2.273737e-13   2.979967
# 15  1.136868e-13   3.081372
# 16  1.136868e-13   2.949655
# 17  1.136868e-13   3.653237
# 18  1.705303e-13   3.555436
# 19  5.684342e-14   3.100307
# 20  5.684342e-14   3.065430
# 21  0.000000e+00   3.156854
# 22  1.136868e-13   4.321016
# 23  3.979039e-13   3.722078
# 24  1.705303e-13   4.129482
# 25  3.410605e-13   5.745502
# 26  5.115908e-13   4.069485
# 27  3.410605e-13   3.152766
# 28  0.000000e+00   6.025637
# 29  5.684342e-14   4.806240
# 30  5.684342e-14   3.861327
# 31  5.684342e-14   5.031233
# 32  3.979039e-13   5.273126
# 33  2.273737e-13   3.756940
# 34  2.842171e-13   2.933172
# 35  3.410605e-13   9.018633
# 36  3.410605e-13   6.873222
# 37  1.136868e-13   3.946528
# 38  5.684342e-14   3.906739
# 39  4.547474e-13   4.228828
# 40  0.000000e+00   4.007426
# 41  0.000000e+00   3.761542
# 42  6.821210e-13  11.588029
# 43  5.684342e-13   6.762884
# 44  3.410605e-13   7.213062
# 45  4.547474e-13   5.824820
# 46  5.684342e-14   3.689166
# 47  1.136868e-13   3.951265
# 48  5.684342e-14   3.839705
# 49  0.000000e+00   7.280480
# 50  6.821210e-13   6.584352
# 51  4.547474e-13   8.686680
# 52  1.250555e-12   9.952127
# 53  0.000000e+00   4.120973
# 54  2.273737e-13   3.198359
# 55  1.136868e-13   3.998306

# %%
iteraciones[0].plot(column = 'h1')
iteraciones[-1].plot(column = 'h1')
# Out:
# <AxesSubplot:>

# %%
iteraciones[0].plot(column = 'h2')
iteraciones[-1].plot(column = 'h2')
# Out:
# <AxesSubplot:>

# %%
print(2)
# Out:
# 2
